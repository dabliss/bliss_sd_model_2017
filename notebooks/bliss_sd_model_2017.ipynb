# %% [markdown]
# # Analysis of the neural model, Bliss & D'Esposito (2017)

# %%
# %matplotlib inline

from dopa_net.engel_and_wang_2011 import plot_engel

# %%
# NOTES FOR CLEAN UP

# (1) No reason for readout_bias to have two networks.  Delete the readout network.  Don't need to re-run
#     simulations.
#
# (2) Same for weak_reset.
#
# (3) Delete the several model scripts that aren't used at all.

# %% [markdown]
# ## Plot Figure 1B

# %%
plot_engel.plot_fig_2a('wm', 'readout_bias_', 90, 1)

# %% [markdown]
# ## Plot Figure 1C

# %%
plot_engel.save_data_for_all_angles('readout_bias_', 'wm')

# %%
plot_engel.save_data_for_plotting_across_delay('readout_bias_', 'wm')

# %%
plot_engel.plot_gabor(('readout_bias_',), ('wm',), delay=6, f_name='original', plot_colors=('black',))
# Out:
# 0.0640268623366

# %% [markdown]
# ## Plot Figure 1D

# %%
plot_engel.plot_across_delay(('readout_bias_',), ('',), ('black',), False, 'wm')
# Out:
# [-0.02198424  0.09582991 -0.00984991  0.06402768  0.12124998]
# [-0.06113746  0.00036678 -0.16302783 -0.10817871 -0.11899815]
# [ 0.0575185   0.24186612  0.13338823  0.33225674  0.46119259]

# %% [markdown]
# ## Plot Figure 2A

# %%
plot_engel.plot_fig_4a('weak_reset_', 'wm')

# %% [markdown]
# ## Plot Figure 2B

# %%
# first bump is at 128 (180)
# second bump is at 80 ()

# choose 104 (halfway) BLUE
# choose 56 (same distance in other direction) RED
plot_engel.plot_firing_rate(('readout_bias_', 'weak_reset_'), (56, 104), 'wm', 112.5)

# %% [markdown]
# ## Plot Figure 2C

# %%
plot_engel.save_data_for_all_angles('weak_reset_', 'wm')

# %%
plot_engel.save_data_for_plotting_across_delay('weak_reset_', 'wm')

# %%
plot_engel.plot_gabor(('weak_reset_',), ('wm',), delay=6, f_name='weak_reset', plot_colors=('black',))
# Out:
# 2.52852137594

# %% [markdown]
# ## Plot Figure 2D

# %%
plot_engel.plot_across_delay(('weak_reset_',), ('',), ('black',), False, 'wm')
# Out:
# [ 2.60483267  2.49940642  2.55417945  2.52879152  2.60096225]
# [ 2.47001735  2.36598839  2.41134222  2.37490775  2.42548885]
# [ 2.73228851  2.62697149  2.69370136  2.67884356  2.76868814]

# %% [markdown]
# ## Plot S1 Fig

# %%
plot_engel.save_data_for_all_angles('no_reset_', 'wm')

# %%
plot_engel.save_data_for_plotting_across_delay('no_reset_', 'wm')

# %%
plot_engel.plot_gabor(('no_reset_',), ('wm',), delay=0, f_name='no_reset0', plot_colors=('black',), plot_fit=False)

# %%
plot_engel.plot_gabor(('no_reset_',), ('wm',), delay=10, f_name='no_reset10', plot_colors=('black',), plot_fit=False)

# %% [markdown]
# ## Plot Figure 3A

# %%
plot_engel.plot_weight_from_180()

# %% [markdown]
# ## Plot Figure 3B

# %%
plot_engel.save_data_for_all_angles('readout_bias_decay_feedforward_corrected_continuous_depression_')

# %%
plot_engel.save_data_for_plotting_across_delay('readout_bias_decay_feedforward_corrected_continuous_depression_')

# %%
plot_engel.plot_gabor(('readout_bias_decay_feedforward_corrected_continuous_depression_',), ('readout',), delay=6, 
                      f_name='depression', plot_colors=('k',))
# Out:
# 2.23188442646
# 0.0194769014542 0.620269808978

# %%
plot_engel.save_data_for_all_angles('readout_bias_decay_feedforward_corrected_continuous_depression_narrow_')

# %%
plot_engel.save_data_for_plotting_across_delay('readout_bias_decay_feedforward_corrected_continuous_depression_narrow_')

# %%
plot_engel.plot_narrow_wide()

# %% [markdown]
# ## Plot Figure 3C

# %%
plot_engel.plot_across_delay(('readout_bias_decay_feedforward_corrected_continuous_depression_',), ('',), ('k',), False,
                              'readout')
# Out:
# [ 0.5202047   1.16382561  1.83086998  2.22859166  2.41078533]
# [ 0.49130732  1.11216623  1.75418828  2.12955224  2.28039858]
# [ 0.54919812  1.21425     1.908007    2.3277549   2.5352637 ]

# %% [markdown]
# ## Plot Figure 3D

# %%
plot_engel.save_data_for_all_angles('readout_bias_decay_feedforward_corrected_continuous_depression_iti3_')

# %%
plot_engel.save_data_for_plotting_across_delay('readout_bias_decay_feedforward_corrected_continuous_depression_iti3_')

# %%
plot_engel.save_data_for_all_angles('readout_bias_decay_feedforward_corrected_continuous_depression_iti6_')

# %%
plot_engel.save_data_for_plotting_across_delay('readout_bias_decay_feedforward_corrected_continuous_depression_iti6_')

# %%
plot_engel.save_data_for_all_angles('readout_bias_decay_feedforward_corrected_continuous_depression_iti10_')

# %%
plot_engel.save_data_for_plotting_across_delay('readout_bias_decay_feedforward_corrected_continuous_depression_iti10_')

# %%
plot_engel.plot_across_iti('readout_bias_decay_feedforward_corrected_continuous_depression_', 3)
# Out:
# [ 1.83086998  1.12058901  0.5944952   0.19973321]
# [ 1.75418828  1.04548214  0.51591781  0.11012683]
# [ 1.908007    1.19654124  0.6701228   0.27172471]

# %% [markdown]
# ## Plot Figure 4A

# %%
plot_engel.save_data_for_all_angles('readout_bias_decay_feedforward_corrected_continuous_depression_adaptation_')

# %%
plot_engel.save_data_for_plotting_across_delay('readout_bias_decay_feedforward_corrected_continuous_depression_adaptation_')

# %%
plot_engel.plot_across_delay(('readout_bias_decay_feedforward_corrected_continuous_depression_adaptation_',), ('',), 
                             ('k',), False,
                              'readout')
# Out:
# [-0.84479924  0.30243686  1.42776097  2.00804251  2.22825402]
# [-0.87173871  0.24330336  1.3483193   1.90829429  2.09648679]
# [-0.81731656  0.35897923  1.50687568  2.10761346  2.35233111]

# %% [markdown]
# ## Plot Figure 4B

# %%
plot_engel.save_data_for_all_angles('readout_bias_decay_feedforward_corrected_continuous_depression_adaptation_iti3_')

# %%
plot_engel.save_data_for_plotting_across_delay('readout_bias_decay_feedforward_corrected_continuous_depression_adaptation_iti3_')

# %%
plot_engel.save_data_for_all_angles('readout_bias_decay_feedforward_corrected_continuous_depression_adaptation_iti6_')

# %%
plot_engel.save_data_for_plotting_across_delay('readout_bias_decay_feedforward_corrected_continuous_depression_adaptation_iti6_')

# %%
plot_engel.save_data_for_all_angles('readout_bias_decay_feedforward_corrected_continuous_depression_adaptation_iti10_')

# %%
plot_engel.save_data_for_plotting_across_delay('readout_bias_decay_feedforward_corrected_continuous_depression_adaptation_iti10_')

# %%
plot_engel.plot_across_iti('readout_bias_decay_feedforward_corrected_continuous_depression_adaptation_', 3)
# Out:
# [ 1.42776097  0.60091873  0.14908281 -0.13459231]
# [ 1.3483193   0.52219351  0.04292228 -0.20141499]
# [ 1.50687568  0.67927106  0.22344987 -0.0412725 ]

# %% [markdown]
# ## Plot Figure 4C

# %%
plot_engel.plot_gabor(('readout_bias_decay_feedforward_corrected_continuous_depression_adaptation_iti10_',), 
                      ('readout',), delay=3, f_name='adapt_iti10', plot_colors=('k',), run=True, plot_fit=False)

# %% [markdown]
# ## Plot S3 Figure

# %%
plot_engel.save_data_for_all_angles('weak_reset_adaptation_', 'wm')

# %%
plot_engel.save_data_for_plotting_across_delay('weak_reset_adaptation_', 'wm')

# %%
plot_engel.plot_across_delay(('weak_reset_adaptation_',), ('',), ('k',), False, 'wm')
# Out:
# [ 0.90391306  0.80178906  0.86208674  0.82799091  0.90806044]
# [ 0.7659717   0.66434054  0.7141797   0.66674878  0.72200536]
# [ 1.0335879   0.93132848  1.00405118  0.98016475  1.08251167]
